# %%
import mlflow
import pickle
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")


mlflow.set_experiment("homework")
print(f"experiment name: '{mlflow.get_experiment_by_name('homework')}'")
# Out:
# tracking URI: 'sqlite:///mlflow.db'
# experiment name: '<Experiment: artifact_location='file:D:/projects/mlops-zoomcamp-2025/02-experiment-tracking/mlruns/1', creation_time=1747031563020, experiment_id='1', last_update_time=1747031563020, lifecycle_stage='active', name='homework', tags={}>'

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)

    df["duration"] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ["PULocationID", "DOLocationID"]
    df[categorical] = df[categorical].astype(str)

    return df


df_train = read_dataframe(
    "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet"
)
df_val = read_dataframe(
    "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet"
)

print(f"train rows: {df_train.shape[0]}")
print(f"val rows: {df_val.shape[0]}")


df_train["PU_DO"] = df_train["PULocationID"] + "_" + df_train["DOLocationID"]
df_val["PU_DO"] = df_val["PULocationID"] + "_" + df_val["DOLocationID"]
# Out:
# train rows: 3009173
# val rows: 2855951

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

rmse_val = np.sqrt(mean_squared_error(y_val, y_pred))

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# c:\Users\timch\miniconda3\Lib\site-packages\xgboost\callback.py:386: UserWarning: [14:51:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation-rmse:9.51000
# [1]	validation-rmse:9.00620
# [2]	validation-rmse:8.55184
# [3]	validation-rmse:8.14361
# [4]	validation-rmse:7.77681
# [5]	validation-rmse:7.44860
# [6]	validation-rmse:7.15569
# [7]	validation-rmse:6.89485
# [8]	validation-rmse:6.66343
# [9]	validation-rmse:6.45746
# [10]	validation-rmse:6.27576
# [11]	validation-rmse:6.11512
# [12]	validation-rmse:5.97404
# [13]	validation-rmse:5.84984
# [14]	validation-rmse:5.74004
# [15]	validation-rmse:5.64374
# [16]	validation-rmse:5.55958
# [17]	validation-rmse:5.48564
# [18]	validation-rmse:5.42052
# [19]	validation-rmse:5.36365
# [20]	validation-rmse:5.31372
# [21]	validation-rmse:5.26988
# [22]	validation-rmse:5.23104
# [23]	validation-rmse:5.19692
# [24]	validation-rmse:5.16699
# [25]	validation-rmse:5.14054
# [26]	validation-rmse:5.11682
# [27]	validation-rmse:5.09591
# [28]	validation-rmse:5.07738
# [29]	validation-rmse:5.06093
# [30]	validation-rmse:5.04621
# [31]	validation-rmse:5.03317
# [32]	validation-rmse:5.02139
# [33]	validation-rmse:5.01087
# [34]	validation-rmse:5.00116
# [35]	validation-rmse:4.99297
# [36]	validation-rmse:4.98489
# [37]	validation-rmse:4.97762
# [38]	validation-rmse:4.97109
# [39]	validation-rmse:4.96505
# [40]	validation-rmse:4.96006
# [41]	validation-rmse:4.95536
# [42]	validation-rmse:4.95090
# [43]	validation-rmse:4.94660
# [44]	validation-rmse:4.94285
# [45]	validation-rmse:4.93947
# [46]	validation-rmse:4.93603
# [47]	validation-rmse:4.93284
# [48]	validation-rmse:4.92976
# [49]	validation-rmse:4.92721
# [50]	validation-rmse:4.92490
# [51]	validation-rmse:4.92239
# [52]	validation-rmse:4.91991
# [53]	validation-rmse:4.91792
# [54]	validation-rmse:4.91580
# [55]	validation-rmse:4.91393
# [56]	validation-rmse:4.91190
# [57]	validation-rmse:4.91020
# [58]	validation-rmse:4.90818
# [59]	validation-rmse:4.90671
# [60]	validation-rmse:4.90504
# [61]	validation-rmse:4.90382
# [62]	validation-rmse:4.90259
# [63]	validation-rmse:4.90135
# [64]	validation-rmse:4.90019
# [65]	validation-rmse:4.89904
# [66]	validation-rmse:4.89788
# [67]	validation-rmse:4.89678
# [68]	validation-rmse:4.89608
# [69]	validation-rmse:4.89525
# [70]	validation-rmse:4.89478
# [71]	validation-rmse:4.89403
# [72]	validation-rmse:4.89350
# [73]	validation-rmse:4.89299
# [74]	validation-rmse:4.89244
# [75]	validation-rmse:4.89175
# [76]	validation-rmse:4.89119
# [77]	validation-rmse:4.89069
# [78]	validation-rmse:4.89016
# [79]	validation-rmse:4.88965
# [80]	validation-rmse:4.88915
# [81]	validation-rmse:4.88873
# [82]	validation-rmse:4.88816
# [83]	validation-rmse:4.88767
# [84]	validation-rmse:4.88728
# [85]	validation-rmse:4.88677
# [86]	validation-rmse:4.88626
# [87]	validation-rmse:4.88583
# [88]	validation-rmse:4.88540
# [89]	validation-rmse:4.88493
# [90]	validation-rmse:4.88456
# [91]	validation-rmse:4.88410
# [92]	validation-rmse:4.88369
# [93]	validation-rmse:4.88319
# [94]	validation-rmse:4.88268
# [95]	validation-rmse:4.88218
# [96]	validation-rmse:4.88175
# [97]	validation-rmse:4.88129
# [98]	validation-rmse:4.88085
# [99]	validation-rmse:4.88046
# [100]	validation-rmse:4.88001
# [101]	validation-rmse:4.87959
# [102]	validation-rmse:4.87921
# [103]	validation-rmse:4.87882
# [104]	validation-rmse:4.87838
# [105]	validation-rmse:4.87791
# [106]	validation-rmse:4.87749
# [107]	validation-rmse:4.87703
# [108]	validation-rmse:4.87651
# [109]	validation-rmse:4.87614
# [110]	validation-rmse:4.87574
# [111]	validation-rmse:4.87531
# [112]	validation-rmse:4.87490
# [113]	validation-rmse:4.87454
# [114]	validation-rmse:4.87414
# [115]	validation-rmse:4.87372
# [116]	validation-rmse:4.87335
# [117]	validation-rmse:4.87287
# [118]	validation-rmse:4.87246
# [119]	validation-rmse:4.87184
# [120]	validation-rmse:4.87148
# [121]	validation-rmse:4.87110
# [122]	validation-rmse:4.87063
# [123]	validation-rmse:4.87022
# [124]	validation-rmse:4.86990
# [125]	validation-rmse:4.86944
# [126]	validation-rmse:4.86904
# [127]	validation-rmse:4.86863
# [128]	validation-rmse:4.86825
# [129]	validation-rmse:4.86791
# [130]	validation-rmse:4.86755
# [131]	validation-rmse:4.86720
# [132]	validation-rmse:4.86680
# [133]	validation-rmse:4.86647
# [134]	validation-rmse:4.86592
# [135]	validation-rmse:4.86536
# [136]	validation-rmse:4.86499
# [137]	validation-rmse:4.86464
# [138]	validation-rmse:4.86425
# [139]	validation-rmse:4.86390
# [140]	validation-rmse:4.86353
# [141]	validation-rmse:4.86318
# [142]	validation-rmse:4.86288
# [143]	validation-rmse:4.86253
# [144]	validation-rmse:4.86221
# [145]	validation-rmse:4.86186
# [146]	validation-rmse:4.86147
# [147]	validation-rmse:4.86114
# [148]	validation-rmse:4.86077
# [149]	validation-rmse:4.86027
# [150]	validation-rmse:4.85993
# [151]	validation-rmse:4.85962
# [152]	validation-rmse:4.85927
# [153]	validation-rmse:4.85890
# [154]	validation-rmse:4.85856
# [155]	validation-rmse:4.85820
# [156]	validation-rmse:4.85788
# [157]	validation-rmse:4.85736
# [158]	validation-rmse:4.85703
# [159]	validation-rmse:4.85660
# [160]	validation-rmse:4.85630
# [161]	validation-rmse:4.85595
# [162]	validation-rmse:4.85564
# [163]	validation-rmse:4.85529
# [164]	validation-rmse:4.85501
# [165]	validation-rmse:4.85465
# [166]	validation-rmse:4.85435
# [167]	validation-rmse:4.85401
# [168]	validation-rmse:4.85363
# [169]	validation-rmse:4.85337
# [170]	validation-rmse:4.85301
# [171]	validation-rmse:4.85273
# [172]	validation-rmse:4.85235
# [173]	validation-rmse:4.85202
# [174]	validation-rmse:4.85171
# [175]	validation-rmse:4.85135
# [176]	validation-rmse:4.85099
# [177]	validation-rmse:4.85069
# [178]	validation-rmse:4.85033
# [179]	validation-rmse:4.85009
# [180]	validation-rmse:4.84973
# [181]	validation-rmse:4.84945
# [182]	validation-rmse:4.84916
# [183]	validation-rmse:4.84878
# [184]	validation-rmse:4.84853
# [185]	validation-rmse:4.84819
# [186]	validation-rmse:4.84785
# [187]	validation-rmse:4.84757
# [188]	validation-rmse:4.84731
# [189]	validation-rmse:4.84690
# [190]	validation-rmse:4.84662
# [191]	validation-rmse:4.84624
# [192]	validation-rmse:4.84589
# [193]	validation-rmse:4.84563
# [194]	validation-rmse:4.84535
# [195]	validation-rmse:4.84494
# [196]	validation-rmse:4.84471
# [197]	validation-rmse:4.84434
# [198]	validation-rmse:4.84407
# [199]	validation-rmse:4.84371
# [200]	validation-rmse:4.84345
# [201]	validation-rmse:4.84311
# [202]	validation-rmse:4.84272
# [203]	validation-rmse:4.84243
# [204]	validation-rmse:4.84216
# [205]	validation-rmse:4.84182
# [206]	validation-rmse:4.84152
# [207]	validation-rmse:4.84123
# [208]	validation-rmse:4.84088
# [209]	validation-rmse:4.84060
# [210]	validation-rmse:4.84032
# [211]	validation-rmse:4.83999
# [212]	validation-rmse:4.83972
# [213]	validation-rmse:4.83940
# [214]	validation-rmse:4.83912
# [215]	validation-rmse:4.83872
# [216]	validation-rmse:4.83844
# [217]	validation-rmse:4.83816
# [218]	validation-rmse:4.83785
# [219]	validation-rmse:4.83737
# [220]	validation-rmse:4.83710
# [221]	validation-rmse:4.83686
# [222]	validation-rmse:4.83655
# [223]	validation-rmse:4.83635
# [224]	validation-rmse:4.83607
# [225]	validation-rmse:4.83581
# [226]	validation-rmse:4.83551
# [227]	validation-rmse:4.83512
# [228]	validation-rmse:4.83490
# [229]	validation-rmse:4.83462
# [230]	validation-rmse:4.83415
# [231]	validation-rmse:4.83391
# [232]	validation-rmse:4.83359
# [233]	validation-rmse:4.83327
# [234]	validation-rmse:4.83298
# [235]	validation-rmse:4.83268
# [236]	validation-rmse:4.83249
# [237]	validation-rmse:4.83218
# [238]	validation-rmse:4.83192
# [239]	validation-rmse:4.83168
# [240]	validation-rmse:4.83144
# [241]	validation-rmse:4.83118
# [242]	validation-rmse:4.83084
# [243]	validation-rmse:4.83057
# [244]	validation-rmse:4.83034
# [245]	validation-rmse:4.83006
# [246]	validation-rmse:4.82983
# [247]	validation-rmse:4.82952
# [248]	validation-rmse:4.82925
# [249]	validation-rmse:4.82902
# [250]	validation-rmse:4.82881
# [251]	validation-rmse:4.82849
# [252]	validation-rmse:4.82827
# [253]	validation-rmse:4.82801
# [254]	validation-rmse:4.82774
# [255]	validation-rmse:4.82746
# [256]	validation-rmse:4.82716
# [257]	validation-rmse:4.82693
# [258]	validation-rmse:4.82654
# [259]	validation-rmse:4.82631
# [260]	validation-rmse:4.82610
# [261]	validation-rmse:4.82588
# [262]	validation-rmse:4.82561
# [263]	validation-rmse:4.82529
# [264]	validation-rmse:4.82503
# [265]	validation-rmse:4.82471
# [266]	validation-rmse:4.82449
# [267]	validation-rmse:4.82423
# [268]	validation-rmse:4.82402
# [269]	validation-rmse:4.82375
# [270]	validation-rmse:4.82345
# [271]	validation-rmse:4.82322
# [272]	validation-rmse:4.82293
# [273]	validation-rmse:4.82268
# [274]	validation-rmse:4.82236
# [275]	validation-rmse:4.82213
# [276]	validation-rmse:4.82190
# [277]	validation-rmse:4.82162
# [278]	validation-rmse:4.82127
# [279]	validation-rmse:4.82103
# [280]	validation-rmse:4.82076
# [281]	validation-rmse:4.82052
# [282]	validation-rmse:4.82026
# [283]	validation-rmse:4.81994
# [284]	validation-rmse:4.81973
# [285]	validation-rmse:4.81951
# [286]	validation-rmse:4.81920
# [287]	validation-rmse:4.81898
# [288]	validation-rmse:4.81878
# [289]	validation-rmse:4.81855
# [290]	validation-rmse:4.81829
# [291]	validation-rmse:4.81810
# [292]	validation-rmse:4.81786
# [293]	validation-rmse:4.81755
# [294]	validation-rmse:4.81734
# [295]	validation-rmse:4.81709
# [296]	validation-rmse:4.81687
# [297]	validation-rmse:4.81664
# [298]	validation-rmse:4.81635
# [299]	validation-rmse:4.81615
# [300]	validation-rmse:4.81592
# [301]	validation-rmse:4.81569
# [302]	validation-rmse:4.81542
# [303]	validation-rmse:4.81514
# [304]	validation-rmse:4.81496
# [305]	validation-rmse:4.81470
# [306]	validation-rmse:4.81439
# [307]	validation-rmse:4.81418
# [308]	validation-rmse:4.81403
# [309]	validation-rmse:4.81376
# [310]	validation-rmse:4.81355
# [311]	validation-rmse:4.81331
# [312]	validation-rmse:4.81311
# [313]	validation-rmse:4.81284
# [314]	validation-rmse:4.81264
# [315]	validation-rmse:4.81243
# [316]	validation-rmse:4.81216
# [317]	validation-rmse:4.81195
# [318]	validation-rmse:4.81168
# [319]	validation-rmse:4.81149
# [320]	validation-rmse:4.81124
# [321]	validation-rmse:4.81101
# [322]	validation-rmse:4.81083
# [323]	validation-rmse:4.81060
# [324]	validation-rmse:4.81032
# [325]	validation-rmse:4.81011
# [326]	validation-rmse:4.80988
# [327]	validation-rmse:4.80959
# [328]	validation-rmse:4.80921
# [329]	validation-rmse:4.80886
# [330]	validation-rmse:4.80828
# [331]	validation-rmse:4.80807
# [332]	validation-rmse:4.80779
# [333]	validation-rmse:4.80761
# [334]	validation-rmse:4.80738
# [335]	validation-rmse:4.80720
# [336]	validation-rmse:4.80695
# [337]	validation-rmse:4.80673
# [338]	validation-rmse:4.80651
# [339]	validation-rmse:4.80628
# [340]	validation-rmse:4.80609
# [341]	validation-rmse:4.80590
# [342]	validation-rmse:4.80566
# [343]	validation-rmse:4.80549
# [344]	validation-rmse:4.80527
# [345]	validation-rmse:4.80505
# [346]	validation-rmse:4.80477
# [347]	validation-rmse:4.80453
# [348]	validation-rmse:4.80427
# [349]	validation-rmse:4.80409
# [350]	validation-rmse:4.80388
# [351]	validation-rmse:4.80354
# [352]	validation-rmse:4.80332
# [353]	validation-rmse:4.80302
# [354]	validation-rmse:4.80282
# [355]	validation-rmse:4.80267
# [356]	validation-rmse:4.80242
# [357]	validation-rmse:4.80221
# [358]	validation-rmse:4.80198
# [359]	validation-rmse:4.80169
# [360]	validation-rmse:4.80148
# [361]	validation-rmse:4.80126
# [362]	validation-rmse:4.80110
# [363]	validation-rmse:4.80087
# [364]	validation-rmse:4.80074
# [365]	validation-rmse:4.80049
# [366]	validation-rmse:4.80020
# [367]	validation-rmse:4.79998
# [368]	validation-rmse:4.79983
# [369]	validation-rmse:4.79955
# [370]	validation-rmse:4.79937
# [371]	validation-rmse:4.79921
# [372]	validation-rmse:4.79900
# [373]	validation-rmse:4.79883
# [374]	validation-rmse:4.79865
# [375]	validation-rmse:4.79849
# [376]	validation-rmse:4.79823
# [377]	validation-rmse:4.79806
# [378]	validation-rmse:4.79781
# [379]	validation-rmse:4.79763
# [380]	validation-rmse:4.79743
# [381]	validation-rmse:4.79721
# [382]	validation-rmse:4.79697
# [383]	validation-rmse:4.79681
# [384]	validation-rmse:4.79659
# [385]	validation-rmse:4.79636
# [386]	validation-rmse:4.79617
# [387]	validation-rmse:4.79601
# [388]	validation-rmse:4.79584
# [389]	validation-rmse:4.79560
# [390]	validation-rmse:4.79542
# [391]	validation-rmse:4.79526
# [392]	validation-rmse:4.79504
# [393]	validation-rmse:4.79484
# [394]	validation-rmse:4.79468
# [395]	validation-rmse:4.79450
# [396]	validation-rmse:4.79432
# [397]	validation-rmse:4.79404
# [398]	validation-rmse:4.79389
# [399]	validation-rmse:4.79369
# [400]	validation-rmse:4.79349
# [401]	validation-rmse:4.79324
# [402]	validation-rmse:4.79309
# [403]	validation-rmse:4.79286
# [404]	validation-rmse:4.79259
# [405]	validation-rmse:4.79245
# [406]	validation-rmse:4.79222
# [407]	validation-rmse:4.79192
# [408]	validation-rmse:4.79150
# [409]	validation-rmse:4.79106
# [410]	validation-rmse:4.79060
# [411]	validation-rmse:4.79026
# [412]	validation-rmse:4.79011
# [413]	validation-rmse:4.78986
# [414]	validation-rmse:4.78969
# [415]	validation-rmse:4.78952
# [416]	validation-rmse:4.78936
# [417]	validation-rmse:4.78918
# [418]	validation-rmse:4.78903
# [419]	validation-rmse:4.78883
# [420]	validation-rmse:4.78855
# [421]	validation-rmse:4.78840
# [422]	validation-rmse:4.78826
# [423]	validation-rmse:4.78808
# [424]	validation-rmse:4.78792
# [425]	validation-rmse:4.78773
# [426]	validation-rmse:4.78759
# [427]	validation-rmse:4.78739
# [428]	validation-rmse:4.78722
# [429]	validation-rmse:4.78702
# [430]	validation-rmse:4.78687
# [431]	validation-rmse:4.78667
# [432]	validation-rmse:4.78650
# [433]	validation-rmse:4.78630
# [434]	validation-rmse:4.78613
# [435]	validation-rmse:4.78594
# [436]	validation-rmse:4.78581
# [437]	validation-rmse:4.78533
# [438]	validation-rmse:4.78510
# [439]	validation-rmse:4.78495
# [440]	validation-rmse:4.78479
# [441]	validation-rmse:4.78440
# [442]	validation-rmse:4.78421
# [443]	validation-rmse:4.78402
# [444]	validation-rmse:4.78388
# [445]	validation-rmse:4.78371
# [446]	validation-rmse:4.78352
# [447]	validation-rmse:4.78333
# [448]	validation-rmse:4.78315
# [449]	validation-rmse:4.78287
# [450]	validation-rmse:4.78268
# [451]	validation-rmse:4.78247
# [452]	validation-rmse:4.78233
# [453]	validation-rmse:4.78215
# [454]	validation-rmse:4.78200
# [455]	validation-rmse:4.78184
# [456]	validation-rmse:4.78164
# [457]	validation-rmse:4.78146
# [458]	validation-rmse:4.78131
# [459]	validation-rmse:4.78117
# [460]	validation-rmse:4.78096
# [461]	validation-rmse:4.78074
# [462]	validation-rmse:4.78052
# [463]	validation-rmse:4.78037
# [464]	validation-rmse:4.78020
# [465]	validation-rmse:4.78005
# [466]	validation-rmse:4.77992
# [467]	validation-rmse:4.77973
# [468]	validation-rmse:4.77959
# [469]	validation-rmse:4.77947
# [470]	validation-rmse:4.77926
# [471]	validation-rmse:4.77903
# [472]	validation-rmse:4.77885
# [473]	validation-rmse:4.77873
# [474]	validation-rmse:4.77853
# [475]	validation-rmse:4.77840
# [476]	validation-rmse:4.77820
# [477]	validation-rmse:4.77801
# [478]	validation-rmse:4.77779
# [479]	validation-rmse:4.77760
# [480]	validation-rmse:4.77742
# [481]	validation-rmse:4.77729
# [482]	validation-rmse:4.77711
# [483]	validation-rmse:4.77699
# [484]	validation-rmse:4.77681
# [485]	validation-rmse:4.77665
# [486]	validation-rmse:4.77651
# [487]	validation-rmse:4.77635
# [488]	validation-rmse:4.77620
# [489]	validation-rmse:4.77608
# [490]	validation-rmse:4.77594
# [491]	validation-rmse:4.77571
# [492]	validation-rmse:4.77554
# [493]	validation-rmse:4.77537
# [494]	validation-rmse:4.77520
# [495]	validation-rmse:4.77502
# [496]	validation-rmse:4.77474
# [497]	validation-rmse:4.77458
# [498]	validation-rmse:4.77438
# [499]	validation-rmse:4.77419
# [500]	validation-rmse:4.77406
# [501]	validation-rmse:4.77388
# [502]	validation-rmse:4.77372
# [503]	validation-rmse:4.77352
# [504]	validation-rmse:4.77337
# [505]	validation-rmse:4.77321
# [506]	validation-rmse:4.77306
# [507]	validation-rmse:4.77292
# [508]	validation-rmse:4.77268
# [509]	validation-rmse:4.77254
# [510]	validation-rmse:4.77236
# [511]	validation-rmse:4.77222
# [512]	validation-rmse:4.77205
# [513]	validation-rmse:4.77188
# [514]	validation-rmse:4.77171
# [515]	validation-rmse:4.77151
# [516]	validation-rmse:4.77140
# [517]	validation-rmse:4.77127
# [518]	validation-rmse:4.77108
# [519]	validation-rmse:4.77092
# [520]	validation-rmse:4.77077
# [521]	validation-rmse:4.77063
# [522]	validation-rmse:4.77047
# [523]	validation-rmse:4.77031
# [524]	validation-rmse:4.77020
# [525]	validation-rmse:4.77002
# [526]	validation-rmse:4.76988
# [527]	validation-rmse:4.76964
# [528]	validation-rmse:4.76952
# [529]	validation-rmse:4.76935
# [530]	validation-rmse:4.76921
# [531]	validation-rmse:4.76906
# [532]	validation-rmse:4.76885
# [533]	validation-rmse:4.76870
# [534]	validation-rmse:4.76852
# [535]	validation-rmse:4.76838
# [536]	validation-rmse:4.76822
# [537]	validation-rmse:4.76806
# [538]	validation-rmse:4.76794
# [539]	validation-rmse:4.76775
# [540]	validation-rmse:4.76760
# [541]	validation-rmse:4.76742
# [542]	validation-rmse:4.76728
# [543]	validation-rmse:4.76700
# [544]	validation-rmse:4.76687
# [545]	validation-rmse:4.76671
# [546]	validation-rmse:4.76658
# [547]	validation-rmse:4.76646
# [548]	validation-rmse:4.76627
# [549]	validation-rmse:4.76612
# [550]	validation-rmse:4.76602
# [551]	validation-rmse:4.76590
# [552]	validation-rmse:4.76573
# [553]	validation-rmse:4.76554
# [554]	validation-rmse:4.76539
# [555]	validation-rmse:4.76526
# [556]	validation-rmse:4.76506
# [557]	validation-rmse:4.76495
# [558]	validation-rmse:4.76481
# [559]	validation-rmse:4.76468
# [560]	validation-rmse:4.76449
# [561]	validation-rmse:4.76436
# [562]	validation-rmse:4.76420
# [563]	validation-rmse:4.76404
# [564]	validation-rmse:4.76390
# [565]	validation-rmse:4.76367
# [566]	validation-rmse:4.76357
# [567]	validation-rmse:4.76343
# [568]	validation-rmse:4.76331
# [569]	validation-rmse:4.76307
# [570]	validation-rmse:4.76293
# [571]	validation-rmse:4.76244
# [572]	validation-rmse:4.76232
# [573]	validation-rmse:4.76223
# [574]	validation-rmse:4.76206
# [575]	validation-rmse:4.76193
# [576]	validation-rmse:4.76179
# [577]	validation-rmse:4.76160
# [578]	validation-rmse:4.76146
# [579]	validation-rmse:4.76133
# [580]	validation-rmse:4.76120
# [581]	validation-rmse:4.76104
# [582]	validation-rmse:4.76088
# [583]	validation-rmse:4.76074
# [584]	validation-rmse:4.76060
# [585]	validation-rmse:4.76041
# [586]	validation-rmse:4.76031
# [587]	validation-rmse:4.76020
# [588]	validation-rmse:4.76004
# [589]	validation-rmse:4.75993
# [590]	validation-rmse:4.75971
# [591]	validation-rmse:4.75951
# [592]	validation-rmse:4.75936
# [593]	validation-rmse:4.75915
# [594]	validation-rmse:4.75906
# [595]	validation-rmse:4.75890
# [596]	validation-rmse:4.75879
# [597]	validation-rmse:4.75865
# [598]	validation-rmse:4.75846
# [599]	validation-rmse:4.75833
# [600]	validation-rmse:4.75820
# [601]	validation-rmse:4.75798
# [602]	validation-rmse:4.75785
# [603]	validation-rmse:4.75771
# [604]	validation-rmse:4.75759
# [605]	validation-rmse:4.75748
# [606]	validation-rmse:4.75736
# [607]	validation-rmse:4.75725
# [608]	validation-rmse:4.75707
# [609]	validation-rmse:4.75692
# [610]	validation-rmse:4.75673
# [611]	validation-rmse:4.75658
# [612]	validation-rmse:4.75645
# [613]	validation-rmse:4.75635
# [614]	validation-rmse:4.75621
# [615]	validation-rmse:4.75604
# [616]	validation-rmse:4.75592
# [617]	validation-rmse:4.75578
# [618]	validation-rmse:4.75566
# [619]	validation-rmse:4.75554
# [620]	validation-rmse:4.75529
# [621]	validation-rmse:4.75516
# [622]	validation-rmse:4.75503
# [623]	validation-rmse:4.75491
# [624]	validation-rmse:4.75473
# [625]	validation-rmse:4.75462
# [626]	validation-rmse:4.75446
# [627]	validation-rmse:4.75436
# [628]	validation-rmse:4.75414
# [629]	validation-rmse:4.75404
# [630]	validation-rmse:4.75390
# [631]	validation-rmse:4.75377
# [632]	validation-rmse:4.75363
# [633]	validation-rmse:4.75350
# [634]	validation-rmse:4.75331
# [635]	validation-rmse:4.75320
# [636]	validation-rmse:4.75301
# [637]	validation-rmse:4.75290
# [638]	validation-rmse:4.75268
# [639]	validation-rmse:4.75259
# [640]	validation-rmse:4.75249
# [641]	validation-rmse:4.75233
# [642]	validation-rmse:4.75220
# [643]	validation-rmse:4.75210
# [644]	validation-rmse:4.75199
# [645]	validation-rmse:4.75181
# [646]	validation-rmse:4.75154
# [647]	validation-rmse:4.75129
# [648]	validation-rmse:4.75117
# [649]	validation-rmse:4.75095
# [650]	validation-rmse:4.75084
# [651]	validation-rmse:4.75072
# [652]	validation-rmse:4.75061
# [653]	validation-rmse:4.75043
# [654]	validation-rmse:4.75031
# [655]	validation-rmse:4.75017
# [656]	validation-rmse:4.75001
# [657]	validation-rmse:4.74989
# [658]	validation-rmse:4.74966
# [659]	validation-rmse:4.74958
# [660]	validation-rmse:4.74943
# [661]	validation-rmse:4.74932
# [662]	validation-rmse:4.74919
# [663]	validation-rmse:4.74909
# [664]	validation-rmse:4.74900
# [665]	validation-rmse:4.74882
# [666]	validation-rmse:4.74871
# [667]	validation-rmse:4.74857
# [668]	validation-rmse:4.74847
# [669]	validation-rmse:4.74829
# [670]	validation-rmse:4.74819
# [671]	validation-rmse:4.74805
# [672]	validation-rmse:4.74789
# [673]	validation-rmse:4.74780
# [674]	validation-rmse:4.74770
# [675]	validation-rmse:4.74748
# [676]	validation-rmse:4.74739
# [677]	validation-rmse:4.74724
# [678]	validation-rmse:4.74714
# [679]	validation-rmse:4.74704
# [680]	validation-rmse:4.74690
# [681]	validation-rmse:4.74680
# [682]	validation-rmse:4.74661
# [683]	validation-rmse:4.74648
# [684]	validation-rmse:4.74634
# [685]	validation-rmse:4.74623
# [686]	validation-rmse:4.74613
# [687]	validation-rmse:4.74603
# [688]	validation-rmse:4.74593
# [689]	validation-rmse:4.74578
# [690]	validation-rmse:4.74567
# [691]	validation-rmse:4.74557
# [692]	validation-rmse:4.74547
# [693]	validation-rmse:4.74534
# [694]	validation-rmse:4.74510
# [695]	validation-rmse:4.74503
# [696]	validation-rmse:4.74492
# [697]	validation-rmse:4.74478
# [698]	validation-rmse:4.74463
# [699]	validation-rmse:4.74454
# [700]	validation-rmse:4.74437
# [701]	validation-rmse:4.74427
# [702]	validation-rmse:4.74412
# [703]	validation-rmse:4.74401
# [704]	validation-rmse:4.74387
# [705]	validation-rmse:4.74373
# [706]	validation-rmse:4.74356
# [707]	validation-rmse:4.74350
# [708]	validation-rmse:4.74330
# [709]	validation-rmse:4.74320
# [710]	validation-rmse:4.74309
# [711]	validation-rmse:4.74295
# [712]	validation-rmse:4.74287
# [713]	validation-rmse:4.74269
# [714]	validation-rmse:4.74258
# [715]	validation-rmse:4.74245
# [716]	validation-rmse:4.74236
# [717]	validation-rmse:4.74215
# [718]	validation-rmse:4.74204
# [719]	validation-rmse:4.74194
# [720]	validation-rmse:4.74179
# [721]	validation-rmse:4.74169
# [722]	validation-rmse:4.74153
# [723]	validation-rmse:4.74140
# [724]	validation-rmse:4.74129
# [725]	validation-rmse:4.74118
# [726]	validation-rmse:4.74096
# [727]	validation-rmse:4.74084
# [728]	validation-rmse:4.74066
# [729]	validation-rmse:4.74058
# [730]	validation-rmse:4.74045
# [731]	validation-rmse:4.74033
# [732]	validation-rmse:4.74025
# [733]	validation-rmse:4.74014
# [734]	validation-rmse:4.74004
# [735]	validation-rmse:4.73978
# [736]	validation-rmse:4.73966
# [737]	validation-rmse:4.73950
# [738]	validation-rmse:4.73934
# [739]	validation-rmse:4.73923
# [740]	validation-rmse:4.73912
# [741]	validation-rmse:4.73902
# [742]	validation-rmse:4.73891
# [743]	validation-rmse:4.73877
# [744]	validation-rmse:4.73867
# [745]	validation-rmse:4.73855
# [746]	validation-rmse:4.73843
# [747]	validation-rmse:4.73832
# [748]	validation-rmse:4.73819
# [749]	validation-rmse:4.73809
# [750]	validation-rmse:4.73797
# [751]	validation-rmse:4.73784
# [752]	validation-rmse:4.73778
# [753]	validation-rmse:4.73769
# [754]	validation-rmse:4.73753
# [755]	validation-rmse:4.73742
# [756]	validation-rmse:4.73728
# [757]	validation-rmse:4.73716
# [758]	validation-rmse:4.73706
# [759]	validation-rmse:4.73691
# [760]	validation-rmse:4.73680
# [761]	validation-rmse:4.73669
# [762]	validation-rmse:4.73659
# [763]	validation-rmse:4.73646
# [764]	validation-rmse:4.73624
# [765]	validation-rmse:4.73611
# [766]	validation-rmse:4.73602
# [767]	validation-rmse:4.73591
# [768]	validation-rmse:4.73581
# [769]	validation-rmse:4.73565
# [770]	validation-rmse:4.73555
# [771]	validation-rmse:4.73545
# [772]	validation-rmse:4.73535
# [773]	validation-rmse:4.73526
# [774]	validation-rmse:4.73514
# [775]	validation-rmse:4.73505
# [776]	validation-rmse:4.73491
# [777]	validation-rmse:4.73482
# [778]	validation-rmse:4.73470
# [779]	validation-rmse:4.73453
# [780]	validation-rmse:4.73440
# [781]	validation-rmse:4.73431
# [782]	validation-rmse:4.73420
# [783]	validation-rmse:4.73406
# [784]	validation-rmse:4.73396
# [785]	validation-rmse:4.73386
# [786]	validation-rmse:4.73378
# [787]	validation-rmse:4.73364
# [788]	validation-rmse:4.73356
# [789]	validation-rmse:4.73344
# [790]	validation-rmse:4.73332
# [791]	validation-rmse:4.73317
# [792]	validation-rmse:4.73309
# [793]	validation-rmse:4.73293
# [794]	validation-rmse:4.73284
# [795]	validation-rmse:4.73278
# [796]	validation-rmse:4.73269
# [797]	validation-rmse:4.73257
# [798]	validation-rmse:4.73248
# [799]	validation-rmse:4.73230
# [800]	validation-rmse:4.73220
# [801]	validation-rmse:4.73202
# [802]	validation-rmse:4.73196
# [803]	validation-rmse:4.73186
# [804]	validation-rmse:4.73177
# [805]	validation-rmse:4.73168
# [806]	validation-rmse:4.73160
# [807]	validation-rmse:4.73150
# [808]	validation-rmse:4.73135
# [809]	validation-rmse:4.73124
# [810]	validation-rmse:4.73114
# [811]	validation-rmse:4.73105
# [812]	validation-rmse:4.73096
# [813]	validation-rmse:4.73080
# [814]	validation-rmse:4.73066
# [815]	validation-rmse:4.73057
# [816]	validation-rmse:4.73048
# [817]	validation-rmse:4.73040
# [818]	validation-rmse:4.73029
# [819]	validation-rmse:4.73021
# [820]	validation-rmse:4.73013
# [821]	validation-rmse:4.72988
# [822]	validation-rmse:4.72976
# [823]	validation-rmse:4.72962
# [824]	validation-rmse:4.72954
# [825]	validation-rmse:4.72946
# [826]	validation-rmse:4.72936
# [827]	validation-rmse:4.72929
# [828]	validation-rmse:4.72913
# [829]	validation-rmse:4.72904
# [830]	validation-rmse:4.72888
# [831]	validation-rmse:4.72877
# [832]	validation-rmse:4.72870
# [833]	validation-rmse:4.72854
# [834]	validation-rmse:4.72845
# [835]	validation-rmse:4.72835
# [836]	validation-rmse:4.72813
# [837]	validation-rmse:4.72801
# [838]	validation-rmse:4.72791
# [839]	validation-rmse:4.72780
# [840]	validation-rmse:4.72768
# [841]	validation-rmse:4.72761
# [842]	validation-rmse:4.72752
# [843]	validation-rmse:4.72740
# [844]	validation-rmse:4.72731
# [845]	validation-rmse:4.72713
# [846]	validation-rmse:4.72706
# [847]	validation-rmse:4.72696
# [848]	validation-rmse:4.72688
# [849]	validation-rmse:4.72676
# [850]	validation-rmse:4.72667
# [851]	validation-rmse:4.72656
# [852]	validation-rmse:4.72647
# [853]	validation-rmse:4.72616
# [854]	validation-rmse:4.72604
# [855]	validation-rmse:4.72592
# [856]	validation-rmse:4.72581
# [857]	validation-rmse:4.72573
# [858]	validation-rmse:4.72556
# [859]	validation-rmse:4.72546
# [860]	validation-rmse:4.72524
# [861]	validation-rmse:4.72514
# [862]	validation-rmse:4.72508
# [863]	validation-rmse:4.72500
# [864]	validation-rmse:4.72489
# [865]	validation-rmse:4.72479
# [866]	validation-rmse:4.72471
# [867]	validation-rmse:4.72453
# [868]	validation-rmse:4.72445
# [869]	validation-rmse:4.72433
# [870]	validation-rmse:4.72424
# [871]	validation-rmse:4.72415
# [872]	validation-rmse:4.72398
# [873]	validation-rmse:4.72387
# [874]	validation-rmse:4.72377
# [875]	validation-rmse:4.72369
# [876]	validation-rmse:4.72361
# [877]	validation-rmse:4.72352
# [878]	validation-rmse:4.72337
# [879]	validation-rmse:4.72331
# [880]	validation-rmse:4.72317
# [881]	validation-rmse:4.72308
# [882]	validation-rmse:4.72298
# [883]	validation-rmse:4.72291
# [884]	validation-rmse:4.72281
# [885]	validation-rmse:4.72268
# [886]	validation-rmse:4.72254
# [887]	validation-rmse:4.72244
# [888]	validation-rmse:4.72232
# [889]	validation-rmse:4.72223
# [890]	validation-rmse:4.72215
# [891]	validation-rmse:4.72206
# [892]	validation-rmse:4.72197
# [893]	validation-rmse:4.72186
# [894]	validation-rmse:4.72176
# [895]	validation-rmse:4.72165
# [896]	validation-rmse:4.72147
# [897]	validation-rmse:4.72138
# [898]	validation-rmse:4.72130
# [899]	validation-rmse:4.72122
# [900]	validation-rmse:4.72113
# [901]	validation-rmse:4.72107
# [902]	validation-rmse:4.72096
# [903]	validation-rmse:4.72085
# [904]	validation-rmse:4.72077
# [905]	validation-rmse:4.72065
# [906]	validation-rmse:4.72058
# [907]	validation-rmse:4.72048
# [908]	validation-rmse:4.72044
# [909]	validation-rmse:4.72036
# [910]	validation-rmse:4.72020
# [911]	validation-rmse:4.72012
# [912]	validation-rmse:4.72007
# [913]	validation-rmse:4.71999
# [914]	validation-rmse:4.71986
# [915]	validation-rmse:4.71977
# [916]	validation-rmse:4.71970
# [917]	validation-rmse:4.71963
# [918]	validation-rmse:4.71952
# [919]	validation-rmse:4.71944
# [920]	validation-rmse:4.71936
# [921]	validation-rmse:4.71926
# [922]	validation-rmse:4.71915
# [923]	validation-rmse:4.71906
# [924]	validation-rmse:4.71879
# [925]	validation-rmse:4.71865
# [926]	validation-rmse:4.71860
# [927]	validation-rmse:4.71846
# [928]	validation-rmse:4.71838
# [929]	validation-rmse:4.71830
# [930]	validation-rmse:4.71822
# [931]	validation-rmse:4.71809
# [932]	validation-rmse:4.71803
# [933]	validation-rmse:4.71795
# [934]	validation-rmse:4.71786
# [935]	validation-rmse:4.71778
# [936]	validation-rmse:4.71769
# [937]	validation-rmse:4.71761
# [938]	validation-rmse:4.71753
# [939]	validation-rmse:4.71743
# [940]	validation-rmse:4.71737
# [941]	validation-rmse:4.71725
# [942]	validation-rmse:4.71714
# [943]	validation-rmse:4.71705
# [944]	validation-rmse:4.71698
# [945]	validation-rmse:4.71687
# [946]	validation-rmse:4.71679
# [947]	validation-rmse:4.71667
# [948]	validation-rmse:4.71658
# [949]	validation-rmse:4.71650
# [950]	validation-rmse:4.71640
# [951]	validation-rmse:4.71634
# [952]	validation-rmse:4.71625
# [953]	validation-rmse:4.71611
# [954]	validation-rmse:4.71604
# [955]	validation-rmse:4.71593
# [956]	validation-rmse:4.71582
# [957]	validation-rmse:4.71573
# [958]	validation-rmse:4.71567
# [959]	validation-rmse:4.71549
# [960]	validation-rmse:4.71542
# [961]	validation-rmse:4.71531
# [962]	validation-rmse:4.71525
# [963]	validation-rmse:4.71519
# [964]	validation-rmse:4.71510
# [965]	validation-rmse:4.71498
# [966]	validation-rmse:4.71473
# [967]	validation-rmse:4.71444
# [968]	validation-rmse:4.71409
# [969]	validation-rmse:4.71389
# [970]	validation-rmse:4.71358
# [971]	validation-rmse:4.71350
# [972]	validation-rmse:4.71339
# [973]	validation-rmse:4.71325
# [974]	validation-rmse:4.71318
# [975]	validation-rmse:4.71310
# [976]	validation-rmse:4.71289
# [977]	validation-rmse:4.71279
# [978]	validation-rmse:4.71270
# [979]	validation-rmse:4.71264
# [980]	validation-rmse:4.71256
# [981]	validation-rmse:4.71250
# [982]	validation-rmse:4.71243
# [983]	validation-rmse:4.71234
# [984]	validation-rmse:4.71226
# [985]	validation-rmse:4.71213
# [986]	validation-rmse:4.71206
# [987]	validation-rmse:4.71198
# [988]	validation-rmse:4.71192
# [989]	validation-rmse:4.71179
# [990]	validation-rmse:4.71167
# [991]	validation-rmse:4.71160
# [992]	validation-rmse:4.71151
# [993]	validation-rmse:4.71138
# [994]	validation-rmse:4.71119
# [995]	validation-rmse:4.71114
# [996]	validation-rmse:4.71104
# [997]	validation-rmse:4.71091
# [998]	validation-rmse:4.71084
# [999]	validation-rmse:4.71079
#   0%|          | 0/50 [16:23<?, ?trial/s, best loss=?]
# job exception: got an unexpected keyword argument 'squared'
#   0%|          | 0/50 [17:48<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=50,
#      16     trials=Trials()
#      17 )
#
# File c:\Users\timch\miniconda3\Lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File c:\Users\timch\miniconda3\Lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File c:\Users\timch\miniconda3\Lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File c:\Users\timch\miniconda3\Lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File c:\Users\timch\miniconda3\Lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File c:\Users\timch\miniconda3\Lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File c:\Users\timch\miniconda3\Lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[22], line 13, in objective(params)
#       5     booster = xgb.train(
#       6         params=params,
#       7         dtrain=train,
#    (...)
#      10         early_stopping_rounds=50
#      11     )
#      12     y_pred = booster.predict(valid)
# ---> 13     rmse = mean_squared_error(y_val, y_pred, squared=False)
#      14     mlflow.log_metric("rmse", rmse)
#      16 return {'loss': rmse, 'status': STATUS_OK}
#
# File c:\Users\timch\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py:194, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191 func_sig = signature(func)
#     193 # Map *args/**kwargs to the function signature
# --> 194 params = func_sig.bind(*args, **kwargs)
#     195 params.apply_defaults()
#     197 # ignore self/cls and positional/keyword markers
#
# File c:\Users\timch\miniconda3\Lib\inspect.py:3277, in Signature.bind(self, *args, **kwargs)
#    3272 def bind(self, /, *args, **kwargs):
#    3273     """Get a BoundArguments object, that maps the passed `args`
#    3274     and `kwargs` to the function's signature.  Raises `TypeError`
#    3275     if the passed arguments can not be bound.
#    3276     """
# -> 3277     return self._bind(args, kwargs)
#
# File c:\Users\timch\miniconda3\Lib\inspect.py:3266, in Signature._bind(self, args, kwargs, partial)
#    3256         raise TypeError(
#    3257             'got some positional-only arguments passed as '
#    3258             'keyword arguments: {arg!r}'.format(
#    (...)
#    3263             ),
#    3264         )
#    3265     else:
# -> 3266         raise TypeError(
#    3267             'got an unexpected keyword argument {arg!r}'.format(
#    3268                 arg=next(iter(kwargs))))
#    3270 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        mlflow.log_metric("rmse", rmse)
